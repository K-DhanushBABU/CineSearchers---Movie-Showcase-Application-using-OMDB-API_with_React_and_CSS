# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushbabuk/CineSearchers/blob/main/DL_LAB_3_SGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GSD PART 1

# %%
import numpy as np

class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # Initialize weights and biases
        self.W1 = np.random.randn(self.input_size, self.hidden_size)
        self.b1 = np.zeros((1, self.hidden_size))
        self.W2 = np.random.randn(self.hidden_size, self.output_size)
        self.b2 = np.zeros((1, self.output_size))

    def forward(self, X):
        # Forward pass through the network
        self.z1 = np.dot(X, self.W1) + self.b1
        self.a1 = self.sigmoid(self.z1)
        self.z2 = np.dot(self.a1, self.W2) + self.b2
        self.output = self.sigmoid(self.z2)
        return self.output

    def backward(self, X, y, output, learning_rate):
        # Backward pass to compute gradients
        self.error = output - y
        self.delta_output = self.error * self.sigmoid_derivative(output)
        self.error_hidden = np.dot(self.delta_output, self.W2.T)
        self.delta_hidden = self.error_hidden * self.sigmoid_derivative(self.a1)

        # Update weights and biases
        self.W2 -= learning_rate * np.dot(self.a1.T, self.delta_output)
        self.b2 -= learning_rate * np.sum(self.delta_output, axis=0, keepdims=True)
        self.W1 -= learning_rate * np.dot(X.T, self.delta_hidden)
        self.b1 -= learning_rate * np.sum(self.delta_hidden, axis=0)

    def train(self, X, y, learning_rate, epochs):
        for epoch in range(epochs):
            # Forward pass
            output = self.forward(X)

            # Backward pass
            self.backward(X, y, output, learning_rate)

            # Compute and print loss (optional)
            loss = np.mean(np.square(y - output))
            if epoch % 100 == 0:
                print(f'Epoch {epoch}, Loss: {loss:.4f}')

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

# Example usage
if __name__ == "__main__":
    # Generate some sample data
    np.random.seed(0)
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    y = np.array([[0], [1], [1], [0]])

    # Create and train the neural network
    input_size = 2
    hidden_size = 3
    output_size = 1
    learning_rate = 0.1
    epochs = 10000

    model = NeuralNetwork(input_size, hidden_size, output_size)
    model.train(X, y, learning_rate, epochs)

    # Evaluate the trained model
    predictions = model.forward(X)
    print("Predictions:", predictions)
# Out:
# Epoch 0, Loss: 0.2579
# Epoch 100, Loss: 0.2344
# Epoch 200, Loss: 0.2292
# Epoch 300, Loss: 0.2231
# Epoch 400, Loss: 0.2160
# Epoch 500, Loss: 0.2080
# Epoch 600, Loss: 0.1993
# Epoch 700, Loss: 0.1901
# Epoch 800, Loss: 0.1806
# Epoch 900, Loss: 0.1709
# Epoch 1000, Loss: 0.1609
# Epoch 1100, Loss: 0.1504
# Epoch 1200, Loss: 0.1396
# Epoch 1300, Loss: 0.1283
# Epoch 1400, Loss: 0.1169
# Epoch 1500, Loss: 0.1056
# Epoch 1600, Loss: 0.0947
# Epoch 1700, Loss: 0.0845
# Epoch 1800, Loss: 0.0751
# Epoch 1900, Loss: 0.0667
# Epoch 2000, Loss: 0.0593
# Epoch 2100, Loss: 0.0528
# Epoch 2200, Loss: 0.0472
# Epoch 2300, Loss: 0.0423
# Epoch 2400, Loss: 0.0382
# Epoch 2500, Loss: 0.0345
# Epoch 2600, Loss: 0.0314
# Epoch 2700, Loss: 0.0287
# Epoch 2800, Loss: 0.0263
# Epoch 2900, Loss: 0.0242
# Epoch 3000, Loss: 0.0224
# Epoch 3100, Loss: 0.0208
# Epoch 3200, Loss: 0.0194
# Epoch 3300, Loss: 0.0181
# Epoch 3400, Loss: 0.0169
# Epoch 3500, Loss: 0.0159
# Epoch 3600, Loss: 0.0150
# ...

# %%
pip install nnfs

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data

# initializing the nnfs
nnfs.init()


class Optimizer_sgd :

  def __init__(self,learning_rate = 1.0):
    self.learning_rate = learning_rate

  def update_params(self,layer):
    layer.weights += -self.learning_rate * layer.dweights
    layer.biases += -self.learning_rate * layer.biases

class Layer_Dense:

  def __init__(self , n_inputs , n_neurons):
    self.weights = 0.01 * np.random.randn(n_inputs , n_neurons)
    self.biases = np.zeros((1,n_neurons))

  def forward(self , inputs):
    self.inputs = inputs
    self.output = np.dot(inputs,self.weights) + self.biases

  def backward(self,dvalues):
    self.dweights = np.dot(self.inputs.T , dvalues)
    self.dbiases =np.sum(dvalues , axis = 0 , keepdims = True)
    self.dinputs = np.dot(dvalues , self.weights.T)

class Activation_ReLU :
  def forward(self , inputs):
    self.inputs = inputs
    self.output = np.maximum(0,inputs)

  def backward(self,dvalues):
    self.dinputs = dvalues.copy()
    self.dinputs[self.inputs <= 0] = 0

class Activation_Softmax:

  def forward(self,inputs):
    self.inputs = inputs
    exp_values = np.exp(inputs - np.max(inputs,axis = 1,keepdims = True))
    probabilities = exp_values / np.sum(exp_values,axis =1,keepdims = True)
    self.output = probabilities

  def backward(self,dvalues):
    self.dinputs = np.empty_like(dvalues)
    for index , (single_output , single_dvalues) in enumerate(zip(self.output,dvalues)):
      single_output = single_output.reshape(-1,1)
      jacobian_matrix = np.diagflat(single_output) - np.dot(single_output,single_output.T)
      self.dinputs[index] = np.dot(jacobian_matrix , single_dvalues)


class Loss:

  def calculate(self,output,y):
    sample_losses = self.forward(output,y)
    data_loss = np.mean(sample_losses)
    return data_loss

class Loss_CategoricalCrossEntropy(Loss):

  def forward(self,y_pred , y_true):

    samples =  len(y_pred)
    y_pred_clipped = np.clip(y_pred , 1e-7 , 1 - 1e-7)

    if len(y_true.shape) == 1:
      correct_confidences = y_pred_clipped[range(samples),y_true]
    elif len(y_true.shape) == 2:
      correct_confidences = np.sum(y_pred_clipped * y_true , axis = 1)

    negative_log_likelihoods = -np.log(correct_confidences)
    return negative_log_likelihoods

  def backward(self,dvalues,y_true):
    samples = len(dvalues)
    labels = len(dvalues[0])

    if len(y_true.shape) == 1:
      y_true = np.eye(labels)[y_true]

    self.dinputs = - y_true / dvalues
    self.dinputs = self.dinputs / samples


class Activation_softmax_Loss_CategoricalCrossentropy :
  def __init__(self):
    self.activation = Activation_Softmax()
    self.loss = Loss_CategoricalCrossEntropy()

  def forward(self,inputs,y_true):
    self.activation.forward(inputs)
    self.output = self.activation.output
    return self.loss.calculate(self.output,y_true)

  def backward(self,dvalues,y_true):
    samples = len(dvalues)
    if len(y_true.shape) == 2:
      y_true = np.argmax(y_true , axis = 1)

    self.dinputs = dvalues.copy()
    self.dinputs[range(samples),y_true] -= 1
    self.dinputs = self.dinputs / samples


X , y = spiral_data(samples = 100 , classes = 3)
dense1 = Layer_Dense(2,64)
activation1 = Activation_ReLU()
dense2 = Layer_Dense(64,3)
loss_activation = Activation_softmax_Loss_CategoricalCrossentropy()

optimizer = Optimizer_sgd()
for epoch in range(10001):
  # performing forward pass of training data through dense layer
  dense1.forward(X)

  # taking output of 1st dense layer and passing it to the 2nd dense layer
  activation1.forward(dense1.output)
  dense2.forward(activation1.output)

  # calculating loss from the output obtained and real output
  loss = loss_activation.forward(dense2.output,y)

  predictions = np.argmax(loss_activation.output , axis = 1)
  if len(y.shape) == 2:
    y = np.argmax(y,axis = 1)
  accuracy = np.mean(predictions == y)

  if not epoch % 100 :
    print(f'epoch : {epoch},'+
          f'Accuracy  : {accuracy : .3f} ,'+
           f'Loss : {loss : .3f}')

  # backward pass updating the weights parameters
  loss_activation.backward(loss_activation.output , y)
  dense2.backward(loss_activation.dinputs)
  activation1.backward(dense2.dinputs)
  dense1.backward(activation1.dinputs)

  optimizer.update_params(dense1)
  optimizer.update_params(dense2)
# Out:
# epoch : 0,Accuracy  :  0.360 ,Loss :  1.099
# epoch : 100,Accuracy  :  0.383 ,Loss :  1.094
# epoch : 200,Accuracy  :  0.387 ,Loss :  1.081
# epoch : 300,Accuracy  :  0.400 ,Loss :  1.078
# epoch : 400,Accuracy  :  0.427 ,Loss :  1.077
# epoch : 500,Accuracy  :  0.420 ,Loss :  1.076
# epoch : 600,Accuracy  :  0.417 ,Loss :  1.076
# epoch : 700,Accuracy  :  0.417 ,Loss :  1.076
# epoch : 800,Accuracy  :  0.410 ,Loss :  1.076
# epoch : 900,Accuracy  :  0.400 ,Loss :  1.076
# epoch : 1000,Accuracy  :  0.393 ,Loss :  1.075
# epoch : 1100,Accuracy  :  0.397 ,Loss :  1.075
# epoch : 1200,Accuracy  :  0.397 ,Loss :  1.075
# epoch : 1300,Accuracy  :  0.393 ,Loss :  1.075
# epoch : 1400,Accuracy  :  0.397 ,Loss :  1.075
# epoch : 1500,Accuracy  :  0.393 ,Loss :  1.075
# epoch : 1600,Accuracy  :  0.400 ,Loss :  1.075
# epoch : 1700,Accuracy  :  0.407 ,Loss :  1.074
# epoch : 1800,Accuracy  :  0.407 ,Loss :  1.074
# epoch : 1900,Accuracy  :  0.403 ,Loss :  1.074
# ...
